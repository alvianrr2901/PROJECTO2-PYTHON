# %%
print('hello world')
# Out:
# hello world

# %%
x = 5
print (x)
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
y = 3.14
print(y)
# Out:
# 3.14

# %%
x+y
# Out:
# 8.14

# %%
print(x+y)
print(x*y)
# Out:
# 8.14
# 15.700000000000001

# %%
print(x/y)
print(x//y) #pembagian dengan pembulatan ke bawah
# Out:
# 1.592356687898089
# 1.0

# %%
print(x%y) #modulo:sisa pembagian
print(x**y) #perpangkatan
# Out:
# 1.8599999999999999
# 156.59064522818883

# %%
import math
print(math.ceil(x/y)) #pembulatan ke atas
print(math.floor(x/y)) #pembulatan ke bawah
# Out:
# 2
# 1

# %% [markdown]
# Boolean

# %%
A = 5 > 3
print(A)
# Out:
# True

# %%
if A:
    print('Hello')
else:
    print('Bye')
# Out:
# Hello

# %%
x = int(input('masukan nilai x: '))
if x > 4:
    print('Nilai X lebih dari 4')
elif x == 4:
    print('Nilai x sama dengan 4')
else:
    print('Nilai x kurang dari 4')
# Out:
# masukan nilai x: 10
# Nilai X lebih dari 4

# %%
x = int(input('Masukkan nilai x: '))
y = int(input('Masukkan nilai y: '))
if (x % 2 == 0) and (y % 3 == 0):
  print('x dan y bilangan yang habis dibagi 2 dan 3')
else:
  print('salah satu dari x atau y adalah bilangan yang tidak habis dibagi 2 dan 3')
# Out:
# Masukkan nilai x: 6
# Masukkan nilai y: 6
# x dan y bilangan yang habis dibagi 2 dan 3

# %%
x = 2.5

# %%
type(x)
# Out:
# float

# %%
x = float(input('input weight in cm: '))
y = float(input('input height in kg: '))

#bmi: weight (kg)/height(m)^2

z = y / ((x*0.01)**2)

print('your BMI is : ', z)

if z < 18.5:
  print('you are underweight')
elif z >= 18.5 and z < 24.9:
  print('you are healthy')
elif z >= 24.9 and z < 29.9:
  print('you are overweight')
else:
  print('you are obesitas')
# Out:
# input weight in cm: 74
# input height in kg: 173
# your BMI is :  315.92403214024836
# you are obesitas

# %%
for i in range(1,6):
  print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# String

# %%
print('Hello World')
# Out:
# Hello World

# %%
d = 'Python'
print(d)
# Out:
# Python

# %%
type(d)
# Out:
# str

# %%
d.lower()
# Out:
# 'python'

# %%
d.capitalize()
# Out:
# 'Python'

# %%
d.swapcase()
# Out:
# 'pYTHON'

# %%
d[0]
# Out:
# 'P'

# %%
for x in range (6):
  print(x*2)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
